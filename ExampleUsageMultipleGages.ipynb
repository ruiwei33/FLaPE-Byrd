# %% [markdown]
# # Notebook to process multiple gages
# by Mike, June 11, 2021

# %%
import os,sys

# 1) add FLaPE-Byrd repository location (pulled from github.com/mikedurand/flape-byrd) to the path
sys.path.append('/Users/mtd/GitHub/FLaPE-Byrd/') 

# 2) import needed modules
from ReachObservations import ReachObservations
from ReachTruth import ReachTruth
from RiverIO import RiverIO
from FlowLawCalibration import FlowLawCalibration
from Domain import Domain
from pprint import pprint
from FlowLaws import MWACN,MWAPN

from IPython.display import display, Markdown

# %%
# 3) provide path to data folders and read directory contents

DataDir='/Users/mtd/OneDrive - The Ohio State University/Data/ArcticDEMHydro/reach_averages/'
DataDirContents=os.scandir(DataDir)

# %%
# 4- 7 Loop over data folders

ConstrainHW_Switch=True #set to true to compute self-constrained height-width data

for entry in DataDirContents:
    if entry.is_dir():
        BaseDir=DataDir + entry.name + '/'
        
        #print(BaseDir)
        
        display(Markdown("**Running "+entry.name+"**"))
        
        #4) Read data and set up data objects
        IO=RiverIO('MetroManTxt',obsFname=BaseDir+'SWOTobs.txt',truthFname=BaseDir+'truth.txt')        
        D=Domain(IO.ObsData)
        Obs=ReachObservations(D,IO.ObsData,ConstrainHW_Switch)
        Truth=ReachTruth(IO.TruthData)
        
        # plot H-W data
        Obs.plotHW()
        
        # 5) For each reach (usually just one for ArcticDEM) and for each flow law variant, do the calibration calculations
        Variants=['Constant-n', 'PowerLaw-n']
        
        ReachData=[]
        for r in range(0,D.nR):
            ReachDict={}
            ReachDict['dA']=Obs.dA[r,:]
            ReachDict['w']=Obs.w[r,:]
            ReachDict['S']=Obs.S[r,:]
            ReachDict['Qtrue']=Truth.Q[r,:]

            ReachData.append(ReachDict)

        cals=[] #make a list of results, indexed by reach #
        for r in range(0,D.nR):    
            FlowLawVariants={} #stash flow law variant objects for each reach in a dict       
            if 'Constant-n' in Variants:     
                FlowLawVariants['Constant-n']=MWACN(ReachData[r]['dA'],ReachData[r]['w'],ReachData[r]['S'])        

            if 'PowerLaw-n' in Variants:
                FlowLawVariants['PowerLaw-n']=MWAPN(ReachData[r]['dA'],ReachData[r]['w'],ReachData[r]['S'])           

            cal={} #make a dictionary of results, keyed off the flow law variant name
            for variant in FlowLawVariants.keys():               
                flow_law_cal=FlowLawCalibration(D,ReachData[r]['Qtrue'],FlowLawVariants[variant])
                flow_law_cal.CalibrateReach()
                cal[variant]=flow_law_cal

            cals.append(cal)
            
        # 6 Visualize results: timeseries and scatterplot
        display(Markdown("**Plots for constant n**"))
        cals[0]['Constant-n'].PlotTimeseries()
        cals[0]['Constant-n'].PlotScatterplot()
        display(Markdown("**Plots for power law n**"))        
        cals[0]['PowerLaw-n'].PlotTimeseries()
        cals[0]['PowerLaw-n'].PlotScatterplot()

        # 7 Error metrics
        display(Markdown("**Stats for constant n**"))
        cals[0]['Constant-n'].Performance.ShowKeyErrorMetrics()
        display(Markdown("**Stats for power law n**"))        
        cals[0]['PowerLaw-n'].Performance.ShowKeyErrorMetrics()
# Out:
# **Running gage22**
# **Plots for constant n**
# **Plots for power law n**
# **Stats for constant n**
# Normalized RMSE: 0.32
# Normalized NSE: 0.11
# **Stats for power law n**
# Normalized RMSE: 1.03
# Normalized NSE: -0.05
# **Running gage13**
# /Users/mtd/GitHub/FLaPE-Byrd/ErrorStats.py:43: RuntimeWarning: invalid value encountered in log
#   self.MSC=log(  sum((self.Qt-QhatAvg)**2)/sum(r**2) -2*2 / self.D.nt  )
# **Plots for constant n**
# **Plots for power law n**
# **Stats for constant n**
# Normalized RMSE: 0.45
# Normalized NSE: -0.04
# **Stats for power law n**
# Normalized RMSE: 1.02
# Normalized NSE: -0.45
# **Running gage71**
# **Plots for constant n**
# **Plots for power law n**
# **Stats for constant n**
# Normalized RMSE: 0.70
# Normalized NSE: 0.15
# **Stats for power law n**
# Normalized RMSE: 0.71
# Normalized NSE: 0.14
# **Running gage4**
# /Users/mtd/GitHub/FLaPE-Byrd/ErrorStats.py:43: RuntimeWarning: invalid value encountered in log
#   self.MSC=log(  sum((self.Qt-QhatAvg)**2)/sum(r**2) -2*2 / self.D.nt  )
# /Users/mtd/GitHub/FLaPE-Byrd/FlowLaws.py:45: RuntimeWarning: overflow encountered in power
#   n=params[0]*((params[1]+self.dA)/self.W)**params[2]
# /Users/mtd/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_numdiff.py:497: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x) - f0
# **Plots for constant n**
# **Plots for power law n**
# **Stats for constant n**
# Normalized RMSE: 0.00
# Normalized NSE: 0.00
# **Stats for power law n**
# Normalized RMSE: 0.22
# Normalized NSE: 0.00
# **Running gage30**
# /Users/mtd/GitHub/FLaPE-Byrd/FlowLaws.py:45: RuntimeWarning: overflow encountered in power
#   n=params[0]*((params[1]+self.dA)/self.W)**params[2]
# /Users/mtd/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_numdiff.py:497: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x) - f0
# **Plots for constant n**
# **Plots for power law n**
# **Stats for constant n**
# Normalized RMSE: 0.20
# Normalized NSE: 0.98
# **Stats for power law n**
# Normalized RMSE: 1.05
# Normalized NSE: 0.46
# **Running gage29**
# **Plots for constant n**
# **Plots for power law n**
# **Stats for constant n**
# Normalized RMSE: 10.01
# Normalized NSE: -0.46
# **Stats for power law n**
# Normalized RMSE: 0.46
# Normalized NSE: 0.51
# **Running gage27**
# /Users/mtd/GitHub/FLaPE-Byrd/FlowLaws.py:45: RuntimeWarning: overflow encountered in power
#   n=params[0]*((params[1]+self.dA)/self.W)**params[2]
# /Users/mtd/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_numdiff.py:497: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x) - f0
# **Plots for constant n**
# **Plots for power law n**
# **Stats for constant n**
# Normalized RMSE: 0.28
# Normalized NSE: -0.02
# **Stats for power law n**
# Normalized RMSE: 0.26
# Normalized NSE: 0.11
# **Running gage19**
# /Users/mtd/GitHub/FLaPE-Byrd/FlowLaws.py:45: RuntimeWarning: overflow encountered in power
#   n=params[0]*((params[1]+self.dA)/self.W)**params[2]
# /Users/mtd/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_numdiff.py:497: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x) - f0
# /Users/mtd/GitHub/FLaPE-Byrd/ErrorStats.py:43: RuntimeWarning: invalid value encountered in log
#   self.MSC=log(  sum((self.Qt-QhatAvg)**2)/sum(r**2) -2*2 / self.D.nt  )
# **Plots for constant n**
# **Plots for power law n**
# **Stats for constant n**
# Normalized RMSE: 0.04
# Normalized NSE: 0.95
# **Stats for power law n**
# Normalized RMSE: 0.99
# Normalized NSE: -0.03
# **Running gage28**
# /Users/mtd/GitHub/FLaPE-Byrd/ErrorStats.py:43: RuntimeWarning: invalid value encountered in log
#   self.MSC=log(  sum((self.Qt-QhatAvg)**2)/sum(r**2) -2*2 / self.D.nt  )
# /Users/mtd/GitHub/FLaPE-Byrd/FlowLaws.py:45: RuntimeWarning: overflow encountered in power
#   n=params[0]*((params[1]+self.dA)/self.W)**params[2]
# /Users/mtd/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_numdiff.py:497: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x) - f0
# **Plots for constant n**
# **Plots for power law n**
# **Stats for constant n**
# Normalized RMSE: 0.15
# Normalized NSE: -21.40
# **Stats for power law n**
# Normalized RMSE: 0.72
# Normalized NSE: -0.94
# **Running gage32**
# **Plots for constant n**
# **Plots for power law n**
# **Stats for constant n**
# Normalized RMSE: 0.59
# Normalized NSE: 0.15
# **Stats for power law n**
# Normalized RMSE: 0.55
# Normalized NSE: 0.25
# **Running gage66**
# **Plots for constant n**
# **Plots for power law n**
# **Stats for constant n**
# Normalized RMSE: 0.96
# Normalized NSE: 0.34
# **Stats for power law n**
# Normalized RMSE: 0.97
# Normalized NSE: 0.32
# **Running gage69**
# **Plots for constant n**
# **Plots for power law n**
# **Stats for constant n**
# Normalized RMSE: 0.07
# Normalized NSE: 0.99
# **Stats for power law n**
# Normalized RMSE: 0.29
# Normalized NSE: 0.89
